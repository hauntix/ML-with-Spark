# %% [markdown]
# ### What is spark?
# "A fast and general engine for large-scale data processing"
#
# ## Why Spark?
#
# ### It's scalable
# ![Screen%20Shot%202019-11-25%20at%202.26.40%20PM.png](attachment:Screen%20Shot%202019-11-25%20at%202.26.40%20PM.png)
#
# ### It's fast
# - "Run programs up to 100x faster then Hadoop MapReduce in memory, or 10x faster on disk."
# - DAG Engine( directed acycylic graph) optimizes workflows
#
# ### It's Hot
# - Amazon
# - eBay
# - NASA JPL
#
# ### It's not that hard
# - Code in oython, java, or scala
# - build around on emain concept : the Resilient Distributed Dataset (RDD)
#
# ### Components of spark
# ![Screen%20Shot%202019-11-25%20at%202.33.42%20PM.png](attachment:Screen%20Shot%202019-11-25%20at%202.33.42%20PM.png)

# %% [markdown]
# # Introducing RDD's
# _Resilient Distributed Dataset_
#
# ### The SparkContext
# - Created by your driver
# - Is responsible for making RDD's resilient and distributed!
# - Creates RDD's
# - The spark shell creates a "sc" object for you
#
# ### Creating RDD's
# - `nums = parrallelize([1,2,3,4])`
# - `sc.textFile("../data/u.data")`
#     - or ` s3n://, hdfs://`
# - `hixeCtx = HiveContext(sc) rows = hiveCtx.sql("SELECT name, age FROM users")
# - Can also create from:
#     - JDBC
#     - Cassandra
#     - HBase
#     - ElastiSearch
#     - JSON, CSV, sequence files, object files, etc...
#
# ### Transforming RDD's
# - map
# - flatmap
# - filter
# - distinct
# - sample
# - union, intersection, subtract, cartesian
#
# #### Map example
# - `rdd = sc.parallelize([1,2,3,4])`
# - `rdd.map(lambda x: x*x)`
# - this yields 1,4,9,16
#
# ## RDD action's
# - collect()
# - count()
# - countByValue()
# - take()
# - top()
# - reduce()
# - ... and more...
#
# ### Lazy Evaluation
# - Nothing actually happends in your driver program until an action is called!
